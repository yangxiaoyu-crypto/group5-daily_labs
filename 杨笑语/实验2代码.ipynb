# %%
# !pip install xlrd --upgrade
# Out:
# Requirement already satisfied: xlrd in d:\anaconda\lib\site-packages (2.0.1)
# Collecting xlrd
#   Using cached xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Using cached xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
# Successfully installed xlrd-2.0.2

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
import os
file_path = 'D:\\Pokemon.xls'  
print(os.path.exists(file_path))  # 检查路径是否存在
print(os.path.isfile(file_path))  # 检查是否是文件（不是文件夹）
# Out:
# True
# True

# %%
df=pd.read_excel('D:\Pokemon.xls')
df
# Out:
#              #                   Name     Type 1     Type 2      Total  \
# 0            1              Bulbasaur      Grass     Poison        318
# 1            2                Ivysaur      Grass     Poison        405
# 2            3               Venusaur      Grass     Poison        525
# 3            3  VenusaurMega Venusaur      Grass     Poison        625
# 4            4             Charmander       Fire        NaN        309
# ..         ...                    ...        ...        ...        ...
# 805        721              Volcanion       Fire      Water        600
# 806  undefined              undefined  undefined  undefined  undefined
# 807  undefined              undefined  undefined  undefined  undefined
# 808        NaN                    NaN        NaN        NaN        NaN
# 809        NaN                    NaN        NaN        NaN        NaN
#
#             HP     Attack    Defense    Sp. Atk    Sp. Def      Speed  \
# 0           45         49         49         65         65         45
# 1           60         62         63         80         80         60
# 2           80         82         83        100        100         80
# 3           80        100        123        122        120         80
# 4           39         52         43         60         50         65
# ..         ...        ...        ...        ...        ...        ...
# 805         80        110        120        130         90         70
# 806  undefined  undefined  undefined  undefined  undefined  undefined
# 807  undefined  undefined  undefined  undefined  undefined  undefined
# 808        NaN        NaN        NaN        NaN        NaN        NaN
# 809        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Generation  Legendary
# 0            1      False
# 1            1      False
# 2            1      False
# 3            1      False
# 4            1      False
# ..         ...        ...
# 805          6          1
# 806  undefined  undefined
# 807  undefined  undefined
# 808        NaN
# 809        NaN
#
# [810 rows x 13 columns]

# %%
df=df[:-4]
df
# Out:
#        #                   Name   Type 1  Type 2 Total  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison   318  45     49      49
# 1      2                Ivysaur    Grass  Poison   405  60     62      63
# 2      3               Venusaur    Grass  Poison   525  80     82      83
# 3      3  VenusaurMega Venusaur    Grass  Poison   625  80    100     123
# 4      4             Charmander     Fire     NaN   309  39     52      43
# ..   ...                    ...      ...     ...   ...  ..    ...     ...
# 801  719                Diancie     Rock   Fairy   600  50    100     150
# 802  719    DiancieMega Diancie     Rock   Fairy   700  50    160     110
# 803  720    HoopaHoopa Confined  Psychic   Ghost   600  80    110      60
# 804  720     HoopaHoopa Unbound  Psychic    Dark   680  80    160      60
# 805  721              Volcanion     Fire   Water   600  80    110     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 0        65      65    45          1     False
# 1        80      80    60          1     False
# 2       100     100    80          1     False
# 3       122     120    80          1     False
# 4        60      50    65          1     False
# ..      ...     ...   ...        ...       ...
# 801     100     150    50          6         1
# 802     160     110   110          6         1
# 803     150     130    70          6         1
# 804     170     130    80          6         1
# 805     130      90    70          6         1
#
# [806 rows x 13 columns]

# %%
condition=df['Type 2'].apply(lambda x: isinstance(x, (int, float)))
df.loc[condition,'Type 2']=np.nan
df
# Out:
# C:\Users\53207\AppData\Local\Temp\ipykernel_2492\2867539432.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[condition,'Type 2']=np.nan
#        #                   Name   Type 1  Type 2 Total  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison   318  45     49      49
# 1      2                Ivysaur    Grass  Poison   405  60     62      63
# 2      3               Venusaur    Grass  Poison   525  80     82      83
# 3      3  VenusaurMega Venusaur    Grass  Poison   625  80    100     123
# 4      4             Charmander     Fire     NaN   309  39     52      43
# ..   ...                    ...      ...     ...   ...  ..    ...     ...
# 801  719                Diancie     Rock   Fairy   600  50    100     150
# 802  719    DiancieMega Diancie     Rock   Fairy   700  50    160     110
# 803  720    HoopaHoopa Confined  Psychic   Ghost   600  80    110      60
# 804  720     HoopaHoopa Unbound  Psychic    Dark   680  80    160      60
# 805  721              Volcanion     Fire   Water   600  80    110     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 0        65      65    45          1     False
# 1        80      80    60          1     False
# 2       100     100    80          1     False
# 3       122     120    80          1     False
# 4        60      50    65          1     False
# ..      ...     ...   ...        ...       ...
# 801     100     150    50          6         1
# 802     160     110   110          6         1
# 803     150     130    70          6         1
# 804     170     130    80          6         1
# 805     130      90    70          6         1
#
# [806 rows x 13 columns]

# %%
df_clean=df.drop_duplicates(subset=['Name'])
df_clean
# Out:
#        #                   Name   Type 1  Type 2 Total  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison   318  45     49      49
# 1      2                Ivysaur    Grass  Poison   405  60     62      63
# 2      3               Venusaur    Grass  Poison   525  80     82      83
# 3      3  VenusaurMega Venusaur    Grass  Poison   625  80    100     123
# 4      4             Charmander     Fire     NaN   309  39     52      43
# ..   ...                    ...      ...     ...   ...  ..    ...     ...
# 801  719                Diancie     Rock   Fairy   600  50    100     150
# 802  719    DiancieMega Diancie     Rock   Fairy   700  50    160     110
# 803  720    HoopaHoopa Confined  Psychic   Ghost   600  80    110      60
# 804  720     HoopaHoopa Unbound  Psychic    Dark   680  80    160      60
# 805  721              Volcanion     Fire   Water   600  80    110     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 0        65      65    45          1     False
# 1        80      80    60          1     False
# 2       100     100    80          1     False
# 3       122     120    80          1     False
# 4        60      50    65          1     False
# ..      ...     ...   ...        ...       ...
# 801     100     150    50          6         1
# 802     160     110   110          6         1
# 803     150     130    70          6         1
# 804     170     130    80          6         1
# 805     130      90    70          6         1
#
# [801 rows x 13 columns]

# %%
has_dup=df_clean.duplicated().any()
if has_dup:
    print("仍有重复值")
else:
    print("无重复值")
# Out:
# 无重复值

# %%
import matplotlib.pyplot as plt
plt.scatter(range(0,df_clean.shape[0]),df_clean.iloc[:,6])

# %%
df_clean['Attack'] = pd.to_numeric(df_clean['Attack'], errors='coerce')
df_clean_2 = df_clean[df_clean['Attack'] <= 400].dropna(subset=['Attack'])
df_clean_2
# Out:
# C:\Users\53207\AppData\Local\Temp\ipykernel_2492\2484456789.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Attack'] = pd.to_numeric(df_clean['Attack'], errors='coerce')
#        #                   Name   Type 1  Type 2 Total  HP  Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison   318  45    49.0      49
# 1      2                Ivysaur    Grass  Poison   405  60    62.0      63
# 2      3               Venusaur    Grass  Poison   525  80    82.0      83
# 3      3  VenusaurMega Venusaur    Grass  Poison   625  80   100.0     123
# 4      4             Charmander     Fire     NaN   309  39    52.0      43
# ..   ...                    ...      ...     ...   ...  ..     ...     ...
# 801  719                Diancie     Rock   Fairy   600  50   100.0     150
# 802  719    DiancieMega Diancie     Rock   Fairy   700  50   160.0     110
# 803  720    HoopaHoopa Confined  Psychic   Ghost   600  80   110.0      60
# 804  720     HoopaHoopa Unbound  Psychic    Dark   680  80   160.0      60
# 805  721              Volcanion     Fire   Water   600  80   110.0     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 0        65      65    45          1     False
# 1        80      80    60          1     False
# 2       100     100    80          1     False
# 3       122     120    80          1     False
# 4        60      50    65          1     False
# ..      ...     ...   ...        ...       ...
# 801     100     150    50          6         1
# 802     160     110   110          6         1
# 803     150     130    70          6         1
# 804     170     130    80          6         1
# 805     130      90    70          6         1
#
# [798 rows x 13 columns]

# %%
condition=df_clean_2['Generation'].apply(lambda x: isinstance(x,(int)))
row_n=df_clean_2.index[condition==False].tolist()
row_n
# Out:
# [771]

# %%
def swap_values(df,row1,col1,col2):
    df.loc[row1,col1],df.loc[row1,col2]=df.loc[row1,col2],df.loc[row1,col1]
swap_values(df_clean_2,771,'Generation','Legendary')
df_clean_2
# Out:
#        #                   Name   Type 1  Type 2 Total  HP  Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison   318  45    49.0      49
# 1      2                Ivysaur    Grass  Poison   405  60    62.0      63
# 2      3               Venusaur    Grass  Poison   525  80    82.0      83
# 3      3  VenusaurMega Venusaur    Grass  Poison   625  80   100.0     123
# 4      4             Charmander     Fire     NaN   309  39    52.0      43
# ..   ...                    ...      ...     ...   ...  ..     ...     ...
# 801  719                Diancie     Rock   Fairy   600  50   100.0     150
# 802  719    DiancieMega Diancie     Rock   Fairy   700  50   160.0     110
# 803  720    HoopaHoopa Confined  Psychic   Ghost   600  80   110.0      60
# 804  720     HoopaHoopa Unbound  Psychic    Dark   680  80   160.0      60
# 805  721              Volcanion     Fire   Water   600  80   110.0     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# 0        65      65    45          1     False
# 1        80      80    60          1     False
# 2       100     100    80          1     False
# 3       122     120    80          1     False
# 4        60      50    65          1     False
# ..      ...     ...   ...        ...       ...
# 801     100     150    50          6         1
# 802     160     110   110          6         1
# 803     150     130    70          6         1
# 804     170     130    80          6         1
# 805     130      90    70          6         1
#
# [798 rows x 13 columns]
